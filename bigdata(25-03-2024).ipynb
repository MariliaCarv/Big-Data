# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
dictdados = {
    'País': ['Japão', 'Reino Unido', 'Paraguai', 'Portugal', 'Estados Unidos'],
    'Número de Brasileiros': [211000, 220000, 240000, 276000, 1700000]
}

# %%
serie = pd.Series(dados['Número de Brasileiros'], index=dados['País'])

# %%
serie.plot()
# Out:
# <Axes: >

# %%
# O grafico mostra  a quantidade de brasileiros que estão em paises  do mundo.
# Tendo quantidade de brasileiros [numero de brasileiros], por países [país]
# E o tamanho da barra representa a proporção dessa quantidade para todo o  total de brasileiros no país correspondente.
